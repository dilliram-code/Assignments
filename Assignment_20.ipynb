# %% [markdown]
# ##### Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.

# %% [markdown]
# Ans:
# A Probability Mass Function (PMF) is used to describe the probability distribution of a discrete random variable. It is a function that gives the probability that a discrete random variable takes on a specific value. The sum of all the probabilities in the PMF is always equal to 1.
#
# For example, consider flipping a fair coin. The PMF for this random variable can be written as:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here, X represents the random variable denoting the outcome of a single coin flip. The PMF shows that the probability of flipping a tails (0) is 0.5, and the probability of flipping a heads (1) is also 0.5.

# %% [markdown]
# A Probability Density Function (PDF) is used to describe the probability distribution of a continuous random variable. It is a function that gives the probability density at a given point, rather than the probability itself. The area under the PDF curve between any two points represents the probability of the random variable falling within that range.

# %% [markdown]
# For example, let us consider a fast food restaurant that advertises a humburger as weighing a quarter pound. If it is weighed, it can be found that it is not exactly o.25 pounds. One randomly selected hamburger might weigh 0.23 pounds while another might weigh 0.27 pounds. Let's say 100000 hamburgers advertised to weigh a quarter-pound. If we weighted the 100000 hamburgers, and created a density curve, most probably we will find the graph as shown below:
#
# In the case of this example, the probability that a randomly selected hamburger weighs between 0.20 and 0.30 pounds is the shaded area.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?

# %% [markdown]
# ###### Ans:
# Cumulative Density Function (CDF) is a function that gives the probability that a random variable takes on a value less than or equal to a specific value. CDF is defined for both discrete and continuous random variables.
#
# For a discrete random variable, the CDF is the sum of all probabilities up to a specific value of the random variable. For a continuous random variable, the CDF is the integral of the PDF from negative infinity up to that value.
#
# CDF is used to describe the probability distribution of a random variable and to calculate the probability of a random variable falling within a certain range. It also helps to determine percentiles of a distribution, which are important in many applications, such as finance and statistics.

# %% [markdown]
# For an example, consider a males

# %% [markdown]
# ![image.png](attachment:image.png)
