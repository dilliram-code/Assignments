# %% [markdown]
# ### March 4, Pyplot Assignment

# %% [markdown]
# ##### Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a scatter plot for age and fare columns in the titanic dataset.

# %%
import seaborn as sns
import plotly.express as px

titanic_df = sns.load_dataset('titanic')

# %%
fig = px.scatter(titanic_df, x = 'age', y = 'fare')
fig.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
import plotly.express as px
import plotly.data as data

# %%
# load the tips dataset from Plotly

tips_df = data.tips()

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a box plot using plotly express

fig = px.box(tips_df, x = 'day', y = 'total_bill', color = 'smoker')
fig.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day" column with the color parameter.

# %%
import plotly.express as px
import plotly.data as data

# %%
tips_df = data.tips()

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.histogram(tips_df, x = 'sex', y = 'total_bill', pattern_shape='smoker', color='day')

# %%
fig.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for the color parameter.
# #### Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the dimensions parameter.

# %%
import plotly.express as px
import plotly.data as data

# %%
iris_df = data.iris()

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
fig = px.scatter_matrix(
iris_df,
dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
color = 'species',
height = 800 ,
width = 800
)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
# displaying scatter matix
fig.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q5. What is Distplot? Using Plotly express, plot a distplot.

# %% [markdown]
# ##### Ans:
# In Plotly, a distplot is a type of plot that shows the distribution of a single variable. It combines a histogram of the variable's values with a smooth density estimate of the distribution.

# %%
import plotly.figure_factory as ff
import numpy as np
np.random.seed(1)

x = np.random.randn(1000)
hist_data = [x]
group_labels = ['distplot'] # name of the dataset

fig = ff.create_distplot(hist_data, group_labels)
fig.show()

# %% [markdown]
# ![image.png](attachment:image.png)
